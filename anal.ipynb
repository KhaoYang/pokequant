# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv(r"C:\Users\ezhen\OneDrive\Desktop\pokequant\final_data_clean.csv")

high = df[df["pricing.cardmarket.avg"] == 2726.5]
print(high)
plt.figure(figsize=(50, 50))
sns.stripplot(data=df, x="rarity", y="pricing.cardmarket.avg")
plt.title("Pokémon Card Price by Rarity")
plt.show()
df["rarity"]
# Out:
# Empty DataFrame
# ...
